# %%
import pandas as pd

# %%
df=pd.read_csv('customer_churn_data.csv')

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4             NaN       2208.32          No   Yes

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.isna().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# MonthlyCharges       0
# ContractType         0
# InternetService    297
# TotalCharges         0
# TechSupport          0
# Churn                0
# dtype: int64

# %%
df['InternetService']=df['InternetService'].fillna("")

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4                       2208.32          No   Yes

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4                       2208.32          No   Yes

# %%
df.describe()
# Out:
#         CustomerID          Age      Tenure  MonthlyCharges  TotalCharges
# count  1000.000000  1000.000000  1000.00000     1000.000000   1000.000000
# mean    500.500000    44.674000    18.97300       74.391290   1404.364060
# std     288.819436     9.797741    18.89257       25.712083   1571.755048
# min       1.000000    12.000000     0.00000       30.000000      0.000000
# 25%     250.750000    38.000000     5.00000       52.357500    345.217500
# 50%     500.500000    45.000000    13.00000       74.060000    872.870000
# 75%     750.250000    51.000000    26.00000       96.102500   1900.175000
# max    1000.000000    83.000000   122.00000      119.960000  12416.250000

# %%
numeric_columns_data=df.select_dtypes(include=['number'])

# %%
numeric_columns_data.corr()
# Out:
#                 CustomerID       Age    Tenure  MonthlyCharges  TotalCharges
# CustomerID        1.000000  0.036730 -0.018585       -0.030504     -0.027490
# Age               0.036730  1.000000  0.000472        0.006362     -0.001896
# Tenure           -0.018585  0.000472  1.000000       -0.014552      0.894868
# MonthlyCharges   -0.030504  0.006362 -0.014552        1.000000      0.304893
# TotalCharges     -0.027490 -0.001896  0.894868        0.304893      1.000000

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# 1       Fiber Optic          0.00         Yes   Yes
# 2       Fiber Optic        127.58          No   Yes
# 3               DSL        818.72         Yes   Yes
# 4                         2208.32          No   Yes
# ..              ...           ...         ...   ...
# 995     Fiber Optic       1522.74         Yes   Yes
# 996                        728.37          No   Yes
# 997     Fiber Optic       1675.80         Yes   Yes
# 998                       4465.56          No   Yes
# 999                         56.67          No   Yes
#
# [1000 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# %%
df['Churn'].value_counts().plot(kind='pie')
plt.title("Churn YES/NO")
plt.show()

# %%
df.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# No     62.54641
# Yes    75.96077
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby(['Churn','Gender'])['MonthlyCharges'].mean()
# Out:
# Churn  Gender
# No     Female    65.091912
#        Male      59.013878
# Yes    Female    74.975064
#        Male      77.082518
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby('Churn')['Tenure'].mean()
# Out:
# Churn
# No     30.264957
# Yes    17.476784
# Name: Tenure, dtype: float64

# %%
df.head(2)
# Out:
#    CustomerID  Age Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49   Male       4           88.35  Month-to-Month
# 1           2   43   Male       0           36.67  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic         353.4         Yes   Yes
# 1     Fiber Optic           0.0         Yes   Yes

# %%
df.groupby('Churn')['Age'].mean()
# Out:
# Churn
# No     43.487179
# Yes    44.831257
# Name: Age, dtype: float64

# %% [markdown]
# ## At the lower trems we can see that monthly charge average decrese

# %%
df.groupby('ContractType')['MonthlyCharges'].mean().plot(kind="bar")
plt.xlabel("Contract type")
plt.ylabel("mean price")
plt.title('Contract Type Average Price')
plt.show()

# %%
df.head(2)
# Out:
#    CustomerID  Age Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49   Male       4           88.35  Month-to-Month
# 1           2   43   Male       0           36.67  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic         353.4         Yes   Yes
# 1     Fiber Optic           0.0         Yes   Yes

# %%
plt.hist(df['MonthlyCharges'])
plt.title("Histogram of monthly Charges")
plt.show()

# %%
plt.hist(df['Tenure'], bins=30)
plt.xlabel("Tenure (months)")
plt.ylabel("Number of Customers")
plt.title("Distribution of Customer Tenure")
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'MonthlyCharges',
#        'ContractType', 'InternetService', 'TotalCharges', 'TechSupport',
#        'Churn'],
#       dtype='object')

# %%
y=df[['Churn']]
X=df[['Age','Gender','Tenure','MonthlyCharges']]

# %% [markdown]
# # We Will use this X for prediction and Y is our Target Variable

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
X['Gender']=X['Gender'].apply(lambda x:1 if x =='Female' else 0)

# %%
X.head(2)
# Out:
#    Age  Gender  Tenure  MonthlyCharges
# 0   49       0       4           88.35
# 1   43       0       0           36.67

# %%
type(X['Gender'][0])
# Out:
# numpy.int64

# %%
y.head(2)
# Out:
#   Churn
# 0   Yes
# 1   Yes

# %%
y['Churn']=y['Churn'].apply(lambda x:1 if x=='Yes' else 0)

# %%
y
# Out:
#      Churn
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      1
# 999      1
#
# [1000 rows x 1 columns]

# %%
type(y['Churn'][0])
# Out:
# numpy.int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
import joblib

# %%
joblib.dump(scaler,'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
X_test=scaler.fit_transform(X_test)

# %%
X_train
# Out:
# array([[ 0.30451508,  0.92528293, -0.83876218,  0.95865003],
#        [ 0.70818046,  0.92528293,  0.06263376, -0.14620967],
#        [-0.5028157 , -1.08075052, -0.25550598, -1.50159907],
#        ...,
#        [ 1.81826027, -1.08075052, -0.46759914,  1.77781103],
#        [-1.00739743, -1.08075052,  0.48682009,  0.93652123],
#        [ 1.0109295 ,  0.92528293, -0.57364573, -1.21827132]],
#       shape=(800, 4))

# %%
X_test
# Out:
# array([[ 0.27795497, -1.07263117,  2.02539235, -0.13631996],
#        [-0.26492583,  0.93228691,  0.39073568, -0.14517119],
#        [ 0.16937881, -1.07263117, -0.29476551, -0.69874168],
#        [-0.37350199,  0.93228691,  1.18169858,  0.10303197],
#        [-0.69923048,  0.93228691,  0.65438998, -1.00484661],
#        [-0.15634967,  0.93228691,  0.4961974 ,  0.68795056],
#        [ 1.36371658,  0.93228691, -0.40022723, -0.16914326],
#        [ 1.0379881 , -1.07263117,  2.34177751,  0.78752686],
#        [-1.02495896,  0.93228691, -0.9802667 ,  0.66692889],
#        [-1.02495896, -1.07263117, -1.03299756,  0.09270554],
#        [-0.15634967,  0.93228691, -0.45295809,  0.6366872 ],
#        [ 0.82083578,  0.93228691,  2.7636244 ,  0.1458129 ],
#        [ 0.49510729,  0.93228691, -0.9802667 ,  0.28669493],
#        [-0.59065432, -1.07263117, -0.82207411,  1.10469583],
#        [ 1.25514042, -1.07263117,  1.39262203, -1.47506805],
#        [-0.15634967,  0.93228691, -0.9802667 , -0.05370851],
#        [ 1.25514042,  0.93228691, -0.50568895, -0.32403973],
#        [-1.78499209, -1.07263117, -0.29476551,  0.83842142],
#        [ 0.16937881, -1.07263117,  0.17981223,  1.21091055],
#        [-0.9163828 , -1.07263117, -0.82207411,  1.54098756],
#        [-1.02495896, -1.07263117, -0.92753584, -0.50659629],
#        [-2.11072057, -1.07263117,  2.39450837,  0.94168573],
#        [-2.21929673, -1.07263117, -0.76934325, -0.93034878],
#        [-0.26492583, -1.07263117,  0.4961974 ,  1.12461109],
#        [ 0.82083578,  0.93228691,  1.07623686,  0.34902232],
#        [-0.69923048,  0.93228691,  3.290933  ,  0.95127456],
#        [ 0.71225962, -1.07263117, -0.13657293,  1.7493602 ],
#        [ 0.49510729, -1.07263117, -0.45295809, -0.69911048],
#        [ 0.38653113,  0.93228691, -0.13657293, -1.24714895],
#        [-0.59065432, -1.07263117,  0.33800482, -0.78872915],
#        [ 1.25514042, -1.07263117, -0.71661239, -0.89162467],
#        [ 0.38653113,  0.93228691, -0.92753584,  1.4546881 ],
#        [ 1.47229274, -1.07263117, -0.29476551, -1.4606848 ],
#        [ 1.0379881 ,  0.93228691, -0.61115067, -1.13466461],
#        [ 0.06080265, -1.07263117, -0.9802667 ,  0.35750475],
#        [ 0.16937881,  0.93228691,  0.28527396,  1.67449357],
#        [-1.4592636 , -1.07263117, -0.55841981,  1.67154316],
#        [ 0.82083578, -1.07263117,  0.02161965, -1.51784898],
#        [-0.37350199,  0.93228691, -0.87480498,  0.8671879 ],
#        [ 0.06080265,  0.93228691, -0.40022723,  1.21865538],
#        [ 0.06080265, -1.07263117, -0.24203465, -1.44556396],
#        [ 0.38653113, -1.07263117, -0.55841981, -0.80089959],
#        [-0.48207815,  0.93228691, -0.29476551, -0.25913074],
#        [-0.69923048,  0.93228691, -0.87480498,  0.24575801],
#        [ 0.38653113,  0.93228691, -0.61115067, -1.33344841],
#        [-0.15634967, -1.07263117, -0.40022723, -1.393563  ],
#        [ 1.25514042,  0.93228691, -0.34749637, -0.68398963],
#        [-1.24211128, -1.07263117, -1.03299756, -0.82634687],
#        [-0.48207815, -1.07263117,  1.44535289,  0.25977245],
#        [-0.9163828 ,  0.93228691, -0.45295809,  0.10008156],
#        [-1.02495896, -1.07263117, -0.55841981, -0.23995308],
#        [-1.13353512, -1.07263117, -0.66388153, -0.48114901],
#        [-0.69923048, -1.07263117,  0.33800482, -0.72308255],
#        [ 0.27795497,  0.93228691, -0.03111121,  0.35418554],
#        [-0.26492583, -1.07263117, -0.34749637, -0.24069068],
#        [-0.59065432,  0.93228691,  0.54892826,  0.85870548],
#        [-1.24211128,  0.93228691,  1.07623686,  0.37963281],
#        [-0.15634967,  0.93228691, -0.18930379,  1.7493602 ]])

# %%
from sklearn.metrics import accuracy_score

# %%
def modelperformance(predictions):
    print("Accuracy Score on model is {}".format(accuracy_score(y_test,predictions)))

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression()

# %%
log_model.fit(X_train, y_train)

# %%
X_train

# %%
# log_model.predict([[40,0,20,80]])
y_pred=log_model.predict(X_test)

# %%
modelperformance(y_pred)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
param_grid={
    "n_neighbors":[3,5,7,9],
    "weights":["uniform","distance"]
}

# %%
gridkn=GridSearchCV(KNeighborsClassifier(),param_grid,cv=5)

# %%
gridkn.fit(X_train,y_train)

# %%
gridkn.best_params_

# %%
y_pred=gridkn.predict(X_test)

# %%
modelperformance(y_pred)

# %%
from sklearn.svm import SVC

# %%
svm=SVC()

# %%
param_grid={
    "C":[0.01,0.1,0.5,1],
    "kernel":["linear","rbf","poly"]
}

# %%
gridsvc=GridSearchCV(svm,param_grid,cv=5)

# %%
gridsvc.fit(X_train,y_train)

# %%
gridsvc.best_params_

# %%
y_pred=gridsvc.predict(X_test)

# %%
modelperformance(y_pred)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
param_grid={
    "criterion":["gini","entropy"],
    "splitter":["best","random"],
    "max_depth":[None,10,20,30],
    "min_samples_split":[2,5,10],
    "min_samples_leaf":[1,2,4],
    
}

# %%
grid_tree=GridSearchCV(DecisionTreeClassifier(),param_grid,cv=5)

# %%
grid_tree.fit(X_train,y_train)

# %%
grid_tree.best_params_

# %%
y_pred=grid_tree.predict(X_test)

# %%
modelperformance(y_pred)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc_model=RandomForestClassifier()

# %%
param_grid={
    "n_estimators":[32,64,128,256],
    "max_features":[2,3,4],
    "bootstrap":[True,False]
}

# %%
grid_rfc=GridSearchCV(rfc_model,param_grid,cv=5)

# %%
grid_rfc.fit(X_train,y_train)

# %%
grid_rfc.best_params_

# %%
y_pred=grid_rfc.predict(X_test)

# %%
best_model=gridsvc.best_estimator_

# %%
joblib.dump(best_model,"model.pkl")

# %%
X.columns
